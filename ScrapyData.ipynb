# %% [markdown]
# <a href="https://colab.research.google.com/github/StalinD10/Modelo-ScrapyData/blob/main/ScrapyData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalación de las librerias o dependencias necesarias
# !pip install beautifulsoup4 requests pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Load dependencies
import json # modulo para trabajar con archivos JSON
import requests # libreria para hacer peticiones HTTP
import pandas as pd # libreria para procesar datos, proporciona funciones para analíticas
from bs4 import BeautifulSoup as bs # Extraer información de paginas web

# %%
# Función que convierte una lista de elementos en un dataframe de pandas
def rowsToDataFrame(rows):
    df = pd.DataFrame(rows[1:], columns=rows[0])
    return df

# %%
# Función para extraer los datos de una tabla HTML
def processTableData(tbl):
    rows = []
    for child in tbl.find('tbody').children: # itera los items internos de la tabla [<tr>]
        row = []
        for td in child: # itera los items internos de la tabla [<td>]
            try:
                item = td.text.replace('\n', '') # recupera el texto del elemento [<td>]
                if item:
                    row.append(item) # Agrega cada elemento de la fila
            except:
                continue
        if len(row) > 0:
            rows.append(row) # agrega todos los campos de una fila de la tabla
    # print(rows)
    return rows

# %%
# Función para exxtrar la data de la URL y procesar el contenido HTML
def processDataHTML(data):
    soup = bs(data['sections'][1]['text'], 'html.parser') # Recupera el item del JSON y lo convierte en contenido HTML
    tbl = soup.find_all('table')[0] # Recupera la tabla del contenido HTML
    # print(tbl.prettify())
    tblRows = processTableData(tbl) # Ejecuta la función apra porcesar el contenido de la Tabla
    return tblRows

# %%
# Read website
r = requests.get('https://www.wikiwand.com/mcs-api/es.wikipedia.org/v1/page/mobile-sections-remaining/Anexo%3AEmpresas_por_ingresos')  # Recuperamos el contenido de la web
# print(r)
table = processDataHTML(json.loads(r.content)) # Formate el contenido en formato JSON
df = rowsToDataFrame(table) # ejecuta la funcion para recupera los datos de la tabla como dataframe de Pandas
df
# Out:
#                Rank                                 Nombre  \
# 0   Millones de USD                                   None
# 1                 1                                Walmart
# 2                 2                                 Amazon
# 3                 3                                Sinopec
# 4                 4                             State Grid
# 5                 5                                  Apple
# 6                 6                           Saudi Aramco
# 7                 7                             Volkswagen
# 8                 8                             CVS Health
# 9                 9                     UnitedHealth Group
# 10               10                             ExxonMobil
# 11               11               China National Petroleum
# 12               12                     Berkshire Hathaway
# 13               13                   McKesson Corporation
# 14               14                                  Shell
# 15               15                               Alphabet
# 16               16                                 Toyota
# 17               17                    Samsung Electronics
# 18               18               China State Construction
# 19               19                              Trafigura
# 20               20                                Foxconn
# 21               21                      AmerisourceBergen
# 22               22                               Glencore
# 23               23                      Ping An Insurance
# 24               24                    Mercedes-Benz Group
# 25               25                                 Costco
# 26               26           Banco Industrial y Comercial
# 27               27                                  Cigna
# 28               28                  Banco de Construcción
# 29               29                                   AT&T
# 30               30                              Microsoft
# 31               31  Corporación de Ingeniería Ferroviaria
# 32               32                                     BP
# 33               33                        Cardinal Health
# 34               34                         Banco Agrícola
# 35               35                   China Life Insurance
#
#                        Industria Ingresos Beneficios  Empleados  \
# 0                           None     None       None       None
# 1             Comercio minorista  572,754     13,940  2,300,000
# 2           Comercio electrónico  469,822     33,364  1,608,000
# 3                       Petróleo  424,812     16,920    553,833
# 4                   Electricidad  386,617      5,580  1,566,000
# 5         Electrónica de consumo  365,820     94,680    154,000
# 6                       Petróleo  359,181    109,972     79,800
# 7                     Automotriz  295,745     22,784    662,575
# 8           Asistencia sanitaria  291,935      7,910    256,500
# 9           Asistencia sanitaria  287,597     17,285    330,000
# 10                      Petróleo  285,640     23,040     72,000
# 11                      Petróleo  283,958      4,575  1,242,245
# 12                  Conglomerado  276,094     89,795    360,000
# 13          Asistencia sanitaria  263,966      1,119     67,500
# 14                      Petróleo  261,504     20,630     87,000
# 15  Tecnología de la información  257,637     76,033    144,056
# 16                    Automotriz  247,816     20,012    366,283
# 17        Electrónica de consumo  244,389     34,881    267,937
# 18                  Construcción  234,425      3,578    356,864
# 19               Materias primas  231,308      3,074      8,619
# 20        Electrónica de consumo  214,599      5,507    878,429
# 21          Asistencia sanitaria  213,989      2,648     40,000
# 22               Materias primas  203,751      4,974     87,822
# 23         Servicios financieros  199,578     22,932    362,035
# 24                    Automotriz  198,547     34,360    288,481
# 25            Comercio minorista  195,929      5,007    288,000
# 26         Servicios financieros  182,794     45,783    439,787
# 27          Asistencia sanitaria  174,078      6,980     72,963
# 28         Servicios financieros  172,000     39,283    373,814
# 29            Telecomunicaciones  168,864     20,081    202,600
# 30  Tecnología de la información  168,090     61,270    181,000
# 31                  Construcción  166,347      1,420    308,483
# 32                      Petróleo  164,195      8,487     68,100
# 33          Asistencia sanitaria  162,467        611     48,000
# 34         Servicios financieros  153,885     31,293    462,592
# 35                       Seguros  144,589      4,648    183,417
#
#                              Sede   Año   Ref
# 0                            None  None  None
# 1                  Estados Unidos  2021   [1]
# 2                  Estados Unidos  2021   [2]
# 3                     China China  2021   [3]
# 4                     China China  2020  None
# 5                  Estados Unidos  2021   [4]
# 6   Arabia Saudita Arabia Saudita  2021   [5]
# 7               Alemania Alemania  2021   [6]
# 8                  Estados Unidos  2021   [7]
# 9                  Estados Unidos  2021   [8]
# 10                 Estados Unidos  2021   [9]
# 11                    China China  2020  None
# 12                 Estados Unidos  2021  [10]
# 13                 Estados Unidos  2021  [11]
# 14        Reino Unido Reino Unido  2021  [12]
# 15                 Estados Unidos  2021  [13]
# 16                    Japón Japón  2021  [14]
# 17    Corea del Sur Corea del Sur  2021  [15]
# 18                    China China  2020  None
# 19              Singapur Singapur  2021  [16]
# 20             República de China  2021  [17]
# 21                 Estados Unidos  2021  [18]
# 22                    Suiza Suiza  2021  [19]
# 23                    China China  2021  [20]
# 24              Alemania Alemania  2021  [21]
# 25                 Estados Unidos  2021  [22]
# 26                    China China  2020  None
# 27                 Estados Unidos  2021  [23]
# 28                    China China  2020  None
# 29                 Estados Unidos  2021  [24]
# 30                 Estados Unidos  2020  None
# 31                    China China  2021  [25]
# 32        Reino Unido Reino Unido  2021  [26]
# 33                 Estados Unidos  2021  [27]
# 34                    China China  2020  None
# 35                    China China  2020  None

# %%
#Inspeccionamos el tipo de dato de cada variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        36 non-null     object
#  1   Nombre      35 non-null     object
#  2   Industria   35 non-null     object
#  3   Ingresos    35 non-null     object
#  4   Beneficios  35 non-null     object
#  5   Empleados   35 non-null     object
#  6   Sede        35 non-null     object
#  7   Año         35 non-null     object
#  8   Ref         27 non-null     object
# dtypes: object(9)
# memory usage: 2.7+ KB

# %%
# Guardamos las datos extraidos como archivo CSV
# se puede aplcair otras opciones para guardar (Base de datos)
df.to_csv('empresasPorIngreso.csv')
